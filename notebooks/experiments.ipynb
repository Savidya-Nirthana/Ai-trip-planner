# %%
import sys
import os
import json
from pathlib import Path
from dotenv import load_dotenv
import random 


project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

load_dotenv(project_root / ".env")

openrouter_key = os.getenv("OPENROUTER_API_KEY")
openai_key = os.getenv("OPENAI_API_KEY")

if not openrouter_key or not openai_key:
    raise ValueError("OPENROUTER_API_KEY or OPENAI_API_KEY not found in environment variables")

from src.infrastructure.config import (
    PROVIDER
)


random.seed(42)
provider = "openrouter" if openrouter_key else "OpenAI"
print("✅ Environment loaded")
print(f"🌐 Provider: {provider}")
print(f"📁 Project root: {project_root}")
# Out:
# ✅ Environment loaded
# 🌐 Provider: openrouter
# 📁 Project root: d:\ai\agentic ai\ai_trip_planner

# %%
from src.infrastructure.config import get_api_key

# %%
from src.infrastructure.llm_provider.llm_client import get_chat_llm
from langchain_openai import ChatOpenAI

llm_client = ChatOpenAI(model="gpt-4o-mini", api_key=os.getenv("OPENROUTER_API_KEY"), base_url="https://openrouter.ai/api/v1")

# llm_client = get_chat_llm()

llm_client.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 13, 'total_tokens': 43, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'cost': 1.995e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 1.995e-05, 'upstream_inference_prompt_cost': 1.95e-06, 'upstream_inference_completions_cost': 1.8e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_414ba99a04', 'id': 'gen-1772396186-iciVHeuf9Oym6dcYAPTX', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cab0b-90c7-70f1-83e3-aebcbee5f857-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1
# ...

# %%
from src.agents.tools.weather_information_tool import WeatherInfoTool

# %%
weather_tool = WeatherInfoTool()    

get_current_weather = weather_tool.weather_tool_list[0]
get_weather_forecast = weather_tool.weather_tool_list[1]

# Test current weather
print("=== Current Weather ===")
result = get_current_weather.invoke({"city": "London"})
print(result)

# Test forecast
print("\n=== Weather Forecast ===")
result = get_weather_forecast.invoke({"city": "London"})
print(result)


# 2. QUICK API KEY CHECK - Run this first to verify setup
print("\n=== API Key Check ===")
api_key = os.getenv("OPENWEATHERMAP_API_KEY")
print(f"API Key found: {'Yes' if api_key else 'No - Check your .env file'}")
# Out:
# === Current Weather ===
# Current temperature in London is 283.97°C with overcast clouds.
#
# === Weather Forecast ===
# Weather forecast for London:
# 2026-03-01: 10.82 degree celcius , overcast clouds
# 2026-03-02: 10.67 degree celcius , overcast clouds
# 2026-03-02: 8.97 degree celcius , overcast clouds
# 2026-03-02: 8.22 degree celcius , overcast clouds
# 2026-03-02: 10.79 degree celcius , broken clouds
# 2026-03-02: 14.36 degree celcius , broken clouds
# 2026-03-02: 13.89 degree celcius , few clouds
# 2026-03-02: 11.63 degree celcius , clear sky
# 2026-03-02: 10.19 degree celcius , clear sky
# 2026-03-03: 9.44 degree celcius , few clouds
#
# === API Key Check ===
# API Key found: Yes
